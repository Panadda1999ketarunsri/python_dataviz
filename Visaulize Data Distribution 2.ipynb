# %%
import pandas
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
import matplotlib

# %% [markdown]
# # Box plot

# %%
# box plot จะบอกการกระจายของข้อมูล บอก outliners
# Q1 คือ ควอไทล์ที่ 1 
# กับ Q3 คือ ควอไทล์ที่ 3

# %%
irisdata = pandas.read_csv('C:\\Users\\acer\\Desktop\\Basic programing\\iris.data',header = None)
irisdata.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %%
setosa_np = irisdata.iloc[:50,:-1].to_numpy()
virginica_np = irisdata.iloc[50:100,:-1].to_numpy()
virginica_np = irisdata.iloc[100:,:-1].to_numpy()

# %% [markdown]
# ### พล็อต box plot ของ setosa

# %%
setosa_np = irisdata.iloc[:50,:-1].to_numpy()
versicolor_np = irisdata.iloc[50:100,:-1].to_numpy()
virginica_np = irisdata.iloc[100:,:-1].to_numpy()

# %%
# อันแรกจะบอกว่า จะplot ให้เป็น 1 แถว 4 หลัก และบอกว่า เป็นอันที่เท่าไหร่
matplotlib.rcParams['figure.figsize']=[15,15]
plt.subplot(1,4,1)
plt.boxplot(setosa_np[:,0])
plt.subplot(1,4,2)
plt.boxplot(setosa_np[:,1])
plt.subplot(1,4,3)
plt.boxplot(setosa_np[:,2])
plt.subplot(1,4,4)
plt.boxplot(setosa_np[:,3])
plt.show()

# %%
setosa_np[:,0]
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.6, 5. , 4.4, 4.9, 5.4, 4.8, 4.8,
#        4.3, 5.8, 5.7, 5.4, 5.1, 5.7, 5.1, 5.4, 5.1, 4.6, 5.1, 4.8, 5. ,
#        5. , 5.2, 5.2, 4.7, 4.8, 5.4, 5.2, 5.5, 4.9, 5. , 5.5, 4.9, 4.4,
#        5.1, 5. , 4.5, 4.4, 5. , 5.1, 4.8, 5.1, 4.6, 5.3, 5. ])

# %%
setosa_np.shape
# Out:
# (50, 4)

# %%
plt.boxplot(setosa_np)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b3a093ba20>,
#   <matplotlib.lines.Line2D at 0x1b3a093bfd0>,
#   <matplotlib.lines.Line2D at 0x1b3a093fcf8>,
#   <matplotlib.lines.Line2D at 0x1b3a093fdd8>,
#   <matplotlib.lines.Line2D at 0x1b3a0948470>,
#   <matplotlib.lines.Line2D at 0x1b3a09487b8>,
#   <matplotlib.lines.Line2D at 0x1b3a0916ba8>,
#   <matplotlib.lines.Line2D at 0x1b3a0916ef0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1b3a093b128>,
#   <matplotlib.lines.Line2D at 0x1b3a093b780>,
#   <matplotlib.lines.Line2D at 0x1b3a092b3c8>,
#   <matplotlib.lines.Line2D at 0x1b3a092b710>,
#   <matplotlib.lines.Line2D at 0x1b3a0948b00>,
#   <matplotlib.lines.Line2D at 0x1b3a0948e48>,
#   <matplotlib.lines.Line2D at 0x1b3a0916fd0>,
#   <matplotlib.lines.Line2D at 0x1b3a09845c0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1b3a093b4a8>,
#   <matplotlib.lines.Line2D at 0x1b3a093f9b0>,
#   <matplotlib.lines.Line2D at 0x1b3a092be48>,
#   <matplotlib.lines.Line2D at 0x1b3a0916860>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b3a093b6a0>,
#   <matplotlib.lines.Line2D at 0x1b3a092ba58>,
#   <matplotlib.lines.Line2D at 0x1b3a0948f28>,
#   <matplotlib.lines.Line2D at 0x1b3a0984908>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b3a093f668>,
#   <matplotlib.lines.Line2D at 0x1b3a092bda0>,
#   <matplotlib.lines.Line2D at 0x1b3a0916518>,
#   <matplotlib.lines.Line2D at 0x1b3a0984c50>],
#  'means': []}

# %% [markdown]
# # HW

# %% [markdown]
# # use boxplot to compare features between 3

# %%
import numpy as np

# %%
f1 = [setosa_np[:,0],versicolor_np[:,0],virginica_np[:,0]]

# %%
f1
# Out:
# [array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.6, 5. , 4.4, 4.9, 5.4, 4.8, 4.8,
#         4.3, 5.8, 5.7, 5.4, 5.1, 5.7, 5.1, 5.4, 5.1, 4.6, 5.1, 4.8, 5. ,
#         5. , 5.2, 5.2, 4.7, 4.8, 5.4, 5.2, 5.5, 4.9, 5. , 5.5, 4.9, 4.4,
#         5.1, 5. , 4.5, 4.4, 5. , 5.1, 4.8, 5.1, 4.6, 5.3, 5. ]),
#  array([7. , 6.4, 6.9, 5.5, 6.5, 5.7, 6.3, 4.9, 6.6, 5.2, 5. , 5.9, 6. ,
#         6.1, 5.6, 6.7, 5.6, 5.8, 6.2, 5.6, 5.9, 6.1, 6.3, 6.1, 6.4, 6.6,
#         6.8, 6.7, 6. , 5.7, 5.5, 5.5, 5.8, 6. , 5.4, 6. , 6.7, 6.3, 5.6,
#         5.5, 5.5, 6.1, 5.8, 5. , 5.6, 5.7, 5.7, 6.2, 5.1, 5.7]),
#  array([6.3, 5.8, 7.1, 6.3, 6.5, 7.6, 4.9, 7.3, 6.7, 7.2, 6.5, 6.4, 6.8,
#         5.7, 5.8, 6.4, 6.5, 7.7, 7.7, 6. , 6.9, 5.6, 7.7, 6.3, 6.7, 7.2,
#         6.2, 6.1, 6.4, 7.2, 7.4, 7.9, 6.4, 6.3, 6.1, 7.7, 6.3, 6.4, 6. ,
#         6.9, 6.7, 6.9, 5.8, 6.8, 6.7, 6.7, 6.3, 6.5, 6.2, 5.9])]

# %%
plt.boxplot(f1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b3a0a75fd0>,
#   <matplotlib.lines.Line2D at 0x1b3a0a80668>,
#   <matplotlib.lines.Line2D at 0x1b3a0ad8a58>,
#   <matplotlib.lines.Line2D at 0x1b3a0ad8da0>,
#   <matplotlib.lines.Line2D at 0x1b3a0ab1f28>,
#   <matplotlib.lines.Line2D at 0x1b3a0aa3518>],
#  'caps': [<matplotlib.lines.Line2D at 0x1b3a0a809b0>,
#   <matplotlib.lines.Line2D at 0x1b3a0a80cf8>,
#   <matplotlib.lines.Line2D at 0x1b3a0ad8e80>,
#   <matplotlib.lines.Line2D at 0x1b3a0ab1470>,
#   <matplotlib.lines.Line2D at 0x1b3a0aa3860>,
#   <matplotlib.lines.Line2D at 0x1b3a0aa3ba8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1b3a0a75e80>,
#   <matplotlib.lines.Line2D at 0x1b3a0ad8710>,
#   <matplotlib.lines.Line2D at 0x1b3a0ab1e48>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b3a0a80dd8>,
#   <matplotlib.lines.Line2D at 0x1b3a0ab17b8>,
#   <matplotlib.lines.Line2D at 0x1b3a0aa3ef0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b3a0ad83c8>,
#   <matplotlib.lines.Line2D at 0x1b3a0ab1b00>,
#   <matplotlib.lines.Line2D at 0x1b3a0aa3fd0>],
#  'means': []}

# %%
plt.boxplot(setosa_np)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b3a0d8a4e0>,
#   <matplotlib.lines.Line2D at 0x1b3a0d8a898>,
#   <matplotlib.lines.Line2D at 0x1b3a0d92c88>,
#   <matplotlib.lines.Line2D at 0x1b3a0d92fd0>,
#   <matplotlib.lines.Line2D at 0x1b3a0dac400>,
#   <matplotlib.lines.Line2D at 0x1b3a0dac748>,
#   <matplotlib.lines.Line2D at 0x1b3a0db8b38>,
#   <matplotlib.lines.Line2D at 0x1b3a0db8e80>],
#  'caps': [<matplotlib.lines.Line2D at 0x1b3a0d8abe0>,
#   <matplotlib.lines.Line2D at 0x1b3a0d8af28>,
#   <matplotlib.lines.Line2D at 0x1b3a0d92f60>,
#   <matplotlib.lines.Line2D at 0x1b3a0d9f6a0>,
#   <matplotlib.lines.Line2D at 0x1b3a0daca90>,
#   <matplotlib.lines.Line2D at 0x1b3a0dacdd8>,
#   <matplotlib.lines.Line2D at 0x1b3a0db8f60>,
#   <matplotlib.lines.Line2D at 0x1b3a0dc5550>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1b3a0d8a0f0>,
#   <matplotlib.lines.Line2D at 0x1b3a0d92940>,
#   <matplotlib.lines.Line2D at 0x1b3a0d9fdd8>,
#   <matplotlib.lines.Line2D at 0x1b3a0db87f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b3a0d8aeb8>,
#   <matplotlib.lines.Line2D at 0x1b3a0d9f9e8>,
#   <matplotlib.lines.Line2D at 0x1b3a0daceb8>,
#   <matplotlib.lines.Line2D at 0x1b3a0dc5898>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b3a0d925f8>,
#   <matplotlib.lines.Line2D at 0x1b3a0d9fd30>,
#   <matplotlib.lines.Line2D at 0x1b3a0db84a8>,
#   <matplotlib.lines.Line2D at 0x1b3a0dc5be0>],
#  'means': []}

# %%
plt.boxplot(f1)
plt.title('Feature 1 Compareison');

# %%
plt.boxplot(f1,labels=['setosa','versicolor','virginica'])
plt.title('Feature 1 Compareison');

# %% [markdown]
# # Bubble chart
# ## การใช้ขนาดของวงกลมแสดงค่าของ data

# %%
plt.scatter(setosa_np[:,0],setosa_np[:,1],s=1000*setosa_np[:,2], c = 'c',alpha=0.2)    #alphaการใช้สีที่โปร่งแสง เพื่อให้เห็นการทับกัน

# %% [markdown]
# # Map

# %%
ls
# Out:
#  Volume in drive C is Acer
#  Volume Serial Number
# 02/21/2020  02:36 PM           633,242 Visualize Data Distribution  ????????? ??????????????????.ipynb
# 02/07/2020  01:48 PM           109,290 ????????? Pre MidTerm.ipynb
#               65 File(s)     46,099,860 bytes
#                3 Dir(s)  19,507,089,408 bytes free

# %%
import pandas

# %%
Debt ='Average Debt.xls'

# %%
Debt_df =pandas.read_excel(Debt)

# %%
Debt_df=pandas.read_excel(Debt,skiprows=3)

# %%
Debt_df
# Out:
#           ภาค และจังหวัด                                         Unnamed: 1  \
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2        ทั่วราชอาณาจักร                                                NaN
# 3               ตอนพิเศษ                                                NaN
# 4          กรุงเทพมหานคร                                                NaN
# ..                   ...                                                ...
# 84              นราธิวาส                                                NaN
# 85                   NaN                                                NaN
# 86                   NaN                                                NaN
# 87                ที่มา:  การสำรวจภาวะเศรษฐกิจและสังคมของครัวเรือน  สำนั...
# 88               Source:  The Household Socio - Economic Survey, Nationa...
#
#         2541      2543      2545      2547      2549      2550      2552  \
# 0     1998.0    2000.0    2002.0    2004.0    2006.0    2007.0    2009.0
# 1        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2    69674.0   68405.0   82485.0  104571.0  116585.0  116681.0  134699.3
# 3   131740.0  126527.0  157730.0  155622.0  155212.0  151168.0  199608.1
# 4   138247.0  135137.0  162199.0  160776.0  158059.0  155396.0  207665.0
# ..       ...       ...       ...       ...       ...       ...       ...
# 84   25071.0   15087.0   34023.0   39297.0   57235.0   36368.0   26246.4
# 85       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 86       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 87       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 88       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#         2554      2556           2558    Region and province
# 0     2011.0    2013.0    2015.000000                    NaN
# 1        NaN       NaN            NaN                    NaN
# 2   134899.9  163087.0  156770.455510          Whole Kingdom
# 3   202157.2  273795.0  171837.386694        Greater Bangkok
# 4   218741.4  275576.8  164705.600000                Bangkok
# ..       ...       ...            ...                    ...
# 84   40942.5   44974.1   40566.900000             Narathiwat
# 85       NaN       NaN            NaN                    NaN
# 86       NaN       NaN            NaN                    NaN
# 87       NaN       NaN            NaN                    NaN
# 88       NaN       NaN            NaN                    NaN
#
# [89 rows x 13 columns]

# %%
Debt_df[['Region and province',2549]]
# Out:
#       Region and province      2549
# 0                     NaN    2006.0
# 1                     NaN       NaN
# 2           Whole Kingdom  116585.0
# 3         Greater Bangkok  155212.0
# 4                 Bangkok  158059.0
# ..                    ...       ...
# 84             Narathiwat   57235.0
# 85                    NaN       NaN
# 86                    NaN       NaN
# 87                    NaN       NaN
# 88                    NaN       NaN
#
# [89 rows x 2 columns]

# %%
Debt_df_debt=Debt_df[['Region and province',2549]]

# %%
Debt_df_debt.drop([0,1,2,3,8,31,49,70,85,86,87,88],axis=0,inplace=True)
# Out:
# C:\Users\acer\Miniconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
Debt_df_debt
# Out:
#                     Region and province      2549
# 4                               Bangkok  158059.0
# 5                          Samut Prakan   95975.0
# 6                            Nonthaburi  179007.0
# 7                          Pathum Thani  193153.0
# 9              Phra Nakhon Si Ayutthaya   53222.0
# ..                                  ...       ...
# 80                                Trang  133375.0
# 81                           Phattalung  117631.0
# 82                              Pattani   82046.0
# 83                                 Yala   55672.0
# 84                           Narathiwat   57235.0
#
# [77 rows x 2 columns]

# %%
Debt_df_debt.head()
# Out:
#                    Region and province      2549
# 4                              Bangkok  158059.0
# 5                         Samut Prakan   95975.0
# 6                           Nonthaburi  179007.0
# 7                         Pathum Thani  193153.0
# 9             Phra Nakhon Si Ayutthaya   53222.0

# %%
import folium
import pandas as pd

# %%
data_to_plot = Debt_df_debt

# %%
data_to_plot
# Out:
#                     Region and province      2549
# 4                               Bangkok  158059.0
# 5                          Samut Prakan   95975.0
# 6                            Nonthaburi  179007.0
# 7                          Pathum Thani  193153.0
# 9              Phra Nakhon Si Ayutthaya   53222.0
# ..                                  ...       ...
# 80                                Trang  133375.0
# 81                           Phattalung  117631.0
# 82                              Pattani   82046.0
# 83                                 Yala   55672.0
# 84                           Narathiwat   57235.0
#
# [77 rows x 2 columns]

# %%
data_to_plot.head()
# Out:
#                    Region and province      2549
# 4                              Bangkok  158059.0
# 5                         Samut Prakan   95975.0
# 6                           Nonthaburi  179007.0
# 7                         Pathum Thani  193153.0
# 9             Phra Nakhon Si Ayutthaya   53222.0

# %%
country_geo = 'thai.json'

# %%
new_col=list()
for d in data_to_plot['Region and province']:
    new_col.append(d.lstrip())
data_to_plot['Region and province']=new_col
# Out:
# C:\Users\acer\Miniconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
map = folium.Map(location=[10,100],zoom_start=5)

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map.choropleth(geo_data=country_geo,data=data_to_plot,
               columns=['Region and province',2549],
               key_on='feature.properties.name',
               fill_color='YlGnBu',fill_opacity=0.7,line_opacity=0.2,
               legend_name='Average Debt')
# Out:
# C:\Users\acer\Miniconda3\lib\site-packages\folium\folium.py:415: FutureWarning: The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
#   FutureWarning

# %%
map.save('plot_data.html')

# %%
from IPython.display import HTML
HTML('<iframe src=plot_data.html width=450 height=700></iframe>')
# Out:
# C:\Users\acer\Miniconda3\lib\site-packages\IPython\core\display.py:694: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src=plot_data.html width=450 height=700></iframe>
