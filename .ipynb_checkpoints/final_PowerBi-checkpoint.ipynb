# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
data_df = pd.read_csv('C:\\Users\\acer\Desktop\\Basic programing\\2019_nCoV_data.csv')

# %%
data_df
# Out:
#        Sno                 Date   Province/State Country          Last Update  \
# 0        1  01/22/2020 12:00:00            Anhui   China  01/22/2020 12:00:00
# 1        2  01/22/2020 12:00:00          Beijing   China  01/22/2020 12:00:00
# 2        3  01/22/2020 12:00:00        Chongqing   China  01/22/2020 12:00:00
# 3        4  01/22/2020 12:00:00           Fujian   China  01/22/2020 12:00:00
# 4        5  01/22/2020 12:00:00            Gansu   China  01/22/2020 12:00:00
# ...    ...                  ...              ...     ...                  ...
# 1714  1715  02/17/2020 22:00:00      Madison, WI      US  2020-02-05T21:53:02
# 1715  1716  02/17/2020 22:00:00       Orange, CA      US  2020-02-01T19:53:03
# 1716  1717  02/17/2020 22:00:00  San Antonio, TX      US  2020-02-13T18:53:02
# 1717  1718  02/17/2020 22:00:00      Seattle, WA      US  2020-02-09T07:03:04
# 1718  1719  02/17/2020 22:00:00        Tempe, AZ      US  2020-02-01T19:43:03
#
# ...

# %%
data_df.isnull().any()
# Out:
# Sno               False
# Date              False
# Province/State     True
# Country           False
# Last Update       False
# Confirmed         False
# Deaths            False
# Recovered         False
# dtype: bool

# %%
data_df['Province/State']=data_df['Province/State'].fillna('Other')

# %%
data_df
# Out:
#        Sno                 Date   Province/State Country          Last Update  \
# 0        1  01/22/2020 12:00:00            Anhui   China  01/22/2020 12:00:00
# 1        2  01/22/2020 12:00:00          Beijing   China  01/22/2020 12:00:00
# 2        3  01/22/2020 12:00:00        Chongqing   China  01/22/2020 12:00:00
# 3        4  01/22/2020 12:00:00           Fujian   China  01/22/2020 12:00:00
# 4        5  01/22/2020 12:00:00            Gansu   China  01/22/2020 12:00:00
# ...    ...                  ...              ...     ...                  ...
# 1714  1715  02/17/2020 22:00:00      Madison, WI      US  2020-02-05T21:53:02
# 1715  1716  02/17/2020 22:00:00       Orange, CA      US  2020-02-01T19:53:03
# 1716  1717  02/17/2020 22:00:00  San Antonio, TX      US  2020-02-13T18:53:02
# 1717  1718  02/17/2020 22:00:00      Seattle, WA      US  2020-02-09T07:03:04
# 1718  1719  02/17/2020 22:00:00        Tempe, AZ      US  2020-02-01T19:43:03
#
# ...

# %%
data_df1 = data[data['Country']!='Mainland China']
data_df2 = data_df1[data_df1['Country']!='Brazil']
data_df3 = data_df2[data_df2['Country']!='Mexico']
data_df4 = data_df3[data_df3['Country']!='China']
data_df5 = data_df4[data_df4['Country']!='Others']

# %%
p= data_df5.groupby('Country').max().reset_index()
p
# Out:
#                  Country   Sno                 Date Province/State  \
# 0              Australia  1696       2/9/2020 23:20       Victoria
# 1                Belgium  1704       2/9/2020 23:20          Other
# 2               Cambodia  1705       2/9/2020 23:20          Other
# 3                 Canada  1706       2/9/2020 23:20    Toronto, ON
# 4                  Egypt  1707  02/17/2020 22:00:00          Other
# 5                Finland  1708       2/9/2020 23:20          Other
# 6                 France  1685       2/9/2020 23:20          Other
# 7                Germany  1683       2/9/2020 23:20          Other
# 8              Hong Kong  1677       2/9/2020 23:20      Hong Kong
# 9                  India  1693       2/9/2020 23:20          Other
# 10                 Italy  1694       2/9/2020 23:20          Other
# 11           Ivory Coast   264  01/27/2020 20:30:00          Other
# 12                 Japan  1676       2/9/2020 23:20          Other
# ...

# %%
plt.bar(p.iloc[:,0],p.iloc[:,5],color = 'c')
plt.title(u'จำนวนผู้ติดเชื้อของแต่ละประเทศ',name='Angsana New',size='30')
plt.xlabel('Country',name='Angsana New',size='25')
plt.ylabel('Confirmed')
# Out:
# Text(0, 0.5, 'Confirmed')

# %%
plt.bar(p.iloc[:,0],p.iloc[:,6],color = 'r')
plt.title(u'จำนวนผู้ที่ตายของแต่ละประเทศ',name='Angsana New',size='30')
plt.xlabel('Country',name='Angsana New',size='25')
plt.ylabel('Deaths')
# Out:
# Text(0, 0.5, 'Deaths')

# %%
plt.bar(p.iloc[:,0],p.iloc[:,7],color = 'g')
plt.title(u'จำนวนผู้ที่รักษาหายของแต่ละประเทศ',name='Angsana New',size='30')
plt.xlabel('Country',name='Angsana New',size='25')
plt.ylabel('Recovered')
# Out:
# Text(0, 0.5, 'Recovered')

# %%
plt.bar(p.iloc[:,0],p.iloc[:,7],color = 'c')
plt.title(u'จำนวนจังหวัด/รัฐ ของแต่ละประเทศ',name='Angsana New',size='30')
plt.xlabel('Country',name='Angsana New',size='25')
plt.ylabel('Province/State')
# Out:
# Text(0, 0.5, 'Province/State')

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import pandas as pd

# %%
data_df = pd.read_csv('C:\\Users\\acer\Desktop\\Basic programing\\2019_nCoV_data.csv')

# %%
data_df
# Out:
#        Sno                 Date   Province/State Country          Last Update  \
# 0        1  01/22/2020 12:00:00            Anhui   China  01/22/2020 12:00:00
# 1        2  01/22/2020 12:00:00          Beijing   China  01/22/2020 12:00:00
# 2        3  01/22/2020 12:00:00        Chongqing   China  01/22/2020 12:00:00
# 3        4  01/22/2020 12:00:00           Fujian   China  01/22/2020 12:00:00
# 4        5  01/22/2020 12:00:00            Gansu   China  01/22/2020 12:00:00
# ...    ...                  ...              ...     ...                  ...
# 1714  1715  02/17/2020 22:00:00      Madison, WI      US  2020-02-05T21:53:02
# 1715  1716  02/17/2020 22:00:00       Orange, CA      US  2020-02-01T19:53:03
# 1716  1717  02/17/2020 22:00:00  San Antonio, TX      US  2020-02-13T18:53:02
# 1717  1718  02/17/2020 22:00:00      Seattle, WA      US  2020-02-09T07:03:04
# 1718  1719  02/17/2020 22:00:00        Tempe, AZ      US  2020-02-01T19:43:03
#
# ...

# %%
data_df = data_df.iloc[:,4]

# %%
data_df
# Out:
# 0       01/22/2020 12:00:00
# 1       01/22/2020 12:00:00
# 2       01/22/2020 12:00:00
# 3       01/22/2020 12:00:00
# 4       01/22/2020 12:00:00
#                ...
# 1714    2020-02-05T21:53:02
# 1715    2020-02-01T19:53:03
# 1716    2020-02-13T18:53:02
# 1717    2020-02-09T07:03:04
# 1718    2020-02-01T19:43:03
# Name: Last Update, Length: 1719, dtype: object

# %%
data_df[0]
# Out:
# '01/22/2020 12:00:00'

# %%
text = ''

# %%
for i in range(len(data_df)):
    text += data_df[i]

# %%
text
# Out:
# '01/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/22/2020 12:00:0001/23/2020 12:00:0001/23/2020 12:00:0001/23/2020 12:00:0001/23/2020 12:00:0001/23/2020 12:00:0001/23/2020 12:00:0001/23/2020 12:00:0001/23/2020 12:00:0001/23/2020 12:00:0001/23/2020 12:00:0001/23/2020 12:00:0001/23/2020 12:00:0001/23/2020 12:00:0001/23/2020 12:00:0001/23/202
# ...

# %%
wordcloud = WordCloud(width=1280, height=853, margin=0,
                      colormap='Blues', font_step=4).generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.margins(x=0, y=0)

# %%
path = 'C:\\Users\\acer\\Downloads\\THSarabunNew\\THSarabunNew Bold.ttf'

# %%
regexp = r"[ก-๙a-zA-Z']+"

# %%
wordcloud = WordCloud(
                      font_path=path, 
                      relative_scaling = 0.3,
                      min_font_size=1,
                      background_color="white",
                      width=1024,
                      height=768,
                      max_words=2000, 
                      colormap='plasma', 
                      scale=3,
                      font_step=4,
                    #   contour_width=3, 
                    #   contour_color='steelblue', 
                      collocations=False,
                      regexp=regexp,
                      margin=2
                      ).generate(text)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
ax.imshow(wordcloud, interpolation='bilinear')
ax.axis("off")
fig.show()
# Out:
# C:\Users\acer\Miniconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   after removing the cwd from sys.path.
